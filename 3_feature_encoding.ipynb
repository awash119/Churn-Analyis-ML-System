# %% [markdown]
# ### 1.Import Dependencies

# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("data\processed\ChurnModelling_Binning_Applied.csv",)
df
# Out:
#      Geography  Gender    Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0       France  Female  42.00       2       0.00              1          1
# 1        Spain  Female  41.00       1   83807.86              1          0
# 2       France  Female  42.00       8  159660.80              3          1
# 3       France  Female  38.91       1       0.00              2          0
# 4        Spain  Female  43.00       2  125510.82              1          1
# ...        ...     ...    ...     ...        ...            ...        ...
# 9995    France    Male  39.00       5       0.00              2          1
# 9996    France    Male  35.00      10   57369.61              1          1
# 9997    France  Female  36.00       7       0.00              1          0
# 9998   Germany    Male  42.00       3   75075.31              2          1
# 9999    France  Female  28.00       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited CreditScoreBins
# ...

# %% [markdown]
# ### 2.Encode Nomial Vairable

# %%
gender_dummies=pd.get_dummies(df['Gender'],prefix='Gender')
credit_score_dummies=pd.get_dummies(df['Geography'],prefix='Geography')
df_encoded=pd.concat([df,credit_score_dummies,gender_dummies],axis=1)
df_encoded.drop(columns=['Geography','Gender'],inplace=True)
df_encoded
# Out:
#         Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     42.00       2       0.00              1          1               1
# 1     41.00       1   83807.86              1          0               1
# 2     42.00       8  159660.80              3          1               0
# 3     38.91       1       0.00              2          0               0
# 4     43.00       2  125510.82              1          1               1
# ...     ...     ...        ...            ...        ...             ...
# 9995  39.00       5       0.00              2          1               0
# 9996  35.00      10   57369.61              1          1               1
# 9997  36.00       7       0.00              1          0               1
# 9998  42.00       3   75075.31              2          1               0
# 9999  28.00       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited CreditScoreBins  Geography_France  \
# ...

# %% [markdown]
# ### 2.Encode Ordinal Variable

# %%
encode_dict_creditscore = {
    'Poor': 0,
    'Fair': 1,
    'Good': 2,
    'Very Good': 3,
    'Excellent': 4
}
df_encoded['CreditScoreBins'] = df_encoded['CreditScoreBins'].map(encode_dict_creditscore)
df_encoded
# Out:
#         Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     42.00       2       0.00              1          1               1
# 1     41.00       1   83807.86              1          0               1
# 2     42.00       8  159660.80              3          1               0
# 3     38.91       1       0.00              2          0               0
# 4     43.00       2  125510.82              1          1               1
# ...     ...     ...        ...            ...        ...             ...
# 9995  39.00       5       0.00              2          1               0
# 9996  35.00      10   57369.61              1          1               1
# 9997  36.00       7       0.00              1          0               1
# 9998  42.00       3   75075.31              2          1               0
# 9999  28.00       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  CreditScoreBins  Geography_France  \
# ...

# %%
df_encoded['CreditScoreBins'].value_counts()
# Out:
# CreditScoreBins
# 1    3331
# 2    2428
# 0    2362
# 3    1224
# 4     655
# Name: count, dtype: int64

# %%
df_encoded.to_csv("data\\processed\\ChurnModelling_Feature_Encoding_Applied.csv",index=False)
